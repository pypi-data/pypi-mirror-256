# %% [markdown]
# # PT3S
# Use SIR 3S Modeldata and SIR 3S Results in pure Python.
#
# With pandas, geopandas, matplotlib and others.
#
# For documentation, test, verification, analysis, reporting, prototyping, play.

# %% [markdown]
# # Deploy

# %%
# !python setup.py clean sdist
# Out:
# running clean
# running sdist
# running egg_info
# writing PT3S.egg-info\PKG-INFO
# writing dependency_links to PT3S.egg-info\dependency_links.txt
# writing requirements to PT3S.egg-info\requires.txt
# writing top-level names to PT3S.egg-info\top_level.txt
# reading manifest file 'PT3S.egg-info\SOURCES.txt'
# writing manifest file 'PT3S.egg-info\SOURCES.txt'
# running check
# creating PT3S-90.14.4.0.dev1
# creating PT3S-90.14.4.0.dev1\PT3S.egg-info
# creating PT3S-90.14.4.0.dev1\UTILS
# creating PT3S-90.14.4.0.dev1\lds
# copying files to PT3S-90.14.4.0.dev1...
# copying Am.py -> PT3S-90.14.4.0.dev1
# copying Dm.py -> PT3S-90.14.4.0.dev1
# copying Dx.py -> PT3S-90.14.4.0.dev1
# copying Lx.py -> PT3S-90.14.4.0.dev1
# copying Mx.py -> PT3S-90.14.4.0.dev1
# copying NFD.py -> PT3S-90.14.4.0.dev1
# copying PT3S.ipynb -> PT3S-90.14.4.0.dev1
# copying README.rst -> PT3S-90.14.4.0.dev1
# copying Rm.py -> PT3S-90.14.4.0.dev1
# copying Xm.py -> PT3S-90.14.4.0.dev1
# ...

# %%
# !twine upload -u __token__ -p pypi-AgEIcHlwaS5vcmcCJDgzZTdkNmUxLTEyNmItNDJhMC05MTJkLTU1ZGJjZWRhYjQ4MgACDasdffFsxLFsicHQzcyJdXQACLFsyLFsiMjA3YTcwMWQtMjZmYS00YWNmLWI3NWEtYjNkZDhkMGIzMDIyIl1dAAAGIGmK2jFxC7M2zmHSJDvcyYGMa2a3tgaHC9Zh5G7o3vmd dist/* --verbose
# Out:
# Uploading distributions to https://upload.pypi.org/legacy/
# INFO     dist\PT3S-90.14.2.0.dev1.tar.gz (11.9 MB)
# INFO     dist\PT3S-90.14.4.0.dev1.tar.gz (332.6 KB)
# INFO     username set by command options
# INFO     password set by command options
# INFO     username: __token__
# INFO     password: <hidden>
# Uploading PT3S-90.14.2.0.dev1.tar.gz
#
#   0% ---------------------------------------- 0.0/12.5 MB • --:-- • ?
#   0% ---------------------------------------- 0.0/12.5 MB • --:-- • ?
#   0% ---------------------------------------- 0.0/12.5 MB • --:-- • ?
#   0% ---------------------------------------- 0.0/12.5 MB • --:-- • ?
#   0% ---------------------------------------- 0.0/12.5 MB • --:-- • ?
#   0% ---------------------------------------- 0.0/12.5 MB • --:-- • ?
#   0% ---------------------------------------- 0.0/12.5 MB • --:-- • ?
#   0% ---------------------------------------- 0.0/12.5 MB • --:-- • ?
# ...

# %% [markdown]
# # Develop (use local PT3S under Development)

# %%
# !pip install -e .
# Out:
# Obtaining file:///C:/Users/wolters/3S/PT3S
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Attempting uninstall: PT3S
#     Found existing installation: PT3S 90.14.4.0.dev1
#     Uninstalling PT3S-90.14.4.0.dev1:
#       Successfully uninstalled PT3S-90.14.4.0.dev1
#   Running setup.py develop for PT3S
# ...
